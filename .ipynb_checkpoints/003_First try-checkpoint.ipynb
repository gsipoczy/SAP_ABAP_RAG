# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import losses

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
batch_size = 32
seed = 42

raw_train_ds = tf.keras.utils.text_dataset_from_directory(
    'test000/train', 
    batch_size=batch_size, 
    validation_split=0.2, 
    subset='training', 
    seed=seed)
# Out:
# Found 10010 files belonging to 10 classes.
# Using 8008 files for training.

# %%
for text_batch, label_batch in raw_train_ds.take(1):
  for i in range(3):
    print("Review", text_batch.numpy()[i])
    print("Label", label_batch.numpy()[i])
# Out:
# Review b'DELETEFLAG is not 4 Deleting a for a scheduling The BAPI does database commit Therefore a delivery confirmation issue for delivery in the SD delivery item 3 in the structure delivery item or a delivery HINTS SALESDOCUMENT The structure DLVITEM must be be filled for not execute a commit so that database can be 1 Required information changes to the order item If must initiate the Database Commit Control FUNCTIONALITY You filled for every Changing of a agreement item 2 these items 2 method to make 1 Generating delivery Posting a goods the deletion indicator made The BAPI can use this must be entered the running application scheduling agreement EXAMPLE BAPITRANSACTIONCOMMIT is available set the structure The order number DLVITEMDATA must also'
# Label 4
# Review b'number that is passed is necessary Movement type following data is necessary method enables you to LANGUAGE EN FUNCTIONALITY This BAPIRET FURTHERSOURCESOFINF INCLUDE BAPIINVENTURWEITERINF the cost center in account assignment object eg item data is passed objects are checked with movement type DSUOMMRESWWAMMRESWWAReservations plant on is returned in FUNCTIONALITY This method MOVETYPE field If account is passed on in activity 03 Display DSUOMMRESBWAMRESBWAReservations the tables LSReservationHeader and Create DSUOMMRESBWAMRESBWAReservations movement type enables you to create checked with activity 01 location STORELOC field Quantity reservations EXAMPLE HINTS The the parameter ZHReservationHeader At QUANTITY field The reservation date RESDATE field The Plant PLANT field Material The header and item LSReservationItems respectively INCLUDE BAPIRET least the following data the field COSTCTR Base list detailed data pertaining assignment is defined for DSUOMMRESWWAMMRESWWAReservations plant The header number is returned in the parameter LSReservation INCLUDE data of the reservation following authorization objects are to a reservation EXAMPLE number MATERIAL field Storage on in the table HINTS The following authorization the movement type the LANGUAGE EN FURTHERSOURCESOFINF INCLUDE data for the reservation LSReservationItems At least the'
# Label 2
# Review b'field BNKANFW The system only takes into account items 0 bnks  0 bnkh  0 Exceptions The bnks  0 bnkindexs  0 and bnkindexh  freight costs The item is relevant for unplanned delivery MRMDISTRIBUTIONBNK distributes unplanned delivery costs among the items in line items on the debit or credit side is record when it reads the parameters for invoice verification to the invoice The item concerned is not a that meet the following conditions The item is allocated  bnkerf bnkh  0 Credit memo bnks  an invoice The unplanned delivery costs are stored in to be invoiced that are distributed among the line items to be posted on the debit side wrbtrh the credit side bnkindexh Number of line items to  wrbtrh  bnkerf bnkh  bnks  bnkerf and bnkindexh  0 Invoice bnkh  bnkerf  bnkindexs  0 and bnkindexh  0 Invoice bnks side that contain unplanned delivery costs bnks Unplanned costs The exception currencyerror is triggered when an error occurs converted value is stored in table field bnkanhw If Value of goods in the line items posted on of unplanned delivery costs is not applicable if the TDRSEG Table containing the invoice items In this function the system should not convert the amount the field indicator BNK is set in Table T169P Parameters Invoice costs Parameters Import parameters IBEZNK Unplanned delivery costs IBUKRS Invoice bnkh  wrbtrh  wrbtrs  bnkerf bnks be posted on the credit side that contain unplanned the following meaning wrbtrs Value of goods in the 1 bnks  0 Credit memo bnkh  bnkerf line items posted on the debit side bnkindexs Number necessary Characteristic  SPACE Default No Characteristic  X delivery costs bnkh Unplanned costs to be invoiced that exception noentryfound is triggered when the system finds no bnkerf  1 bnkh  0 bnkindexs  0 Verification In this case the system posts unplanned delivery are distributed among the line items to be posted entered Formulae bnkindexs  0 and bnkindexh  0 unplanned delivery costs that the system distributes to the Company code IBUDAT Posting date of the invoice document during conversion of an amount from a foreign currency should convert the amount to the local currency the DEENLANGSWITCHNOTRANSLATION DEENLANGSWITCHNOTRANSLATION DEENLANGSWITCHNOTRANSLATION DEENLANGSWITCHNOTRANSLATION FUNCTIONALITY The function module to the local currency EXAMPLE HINTS If the system  bnkh  bnkerf Credit memo bnks  wrbtrs of line items to be posted on the debit Yes Export parameters None Changing parameters None Table parameters invoice IUMRECHNEN Indicates whether conversion to local currency is module the system distributes unplanned delivery costs among all IWAERS Currency key in the invoice IXRECH Indicator post costs to a separate account The amount of the material items that meet the conditions listed above Distribution planned delivery costs item such as customs duty or on the credit side bnkerf The unplanned delivery costs calculated using the following formulae The variables used have'
# Label 9

# %%
for i in range(len(raw_train_ds.class_names)):
    print("Label", i, "corresponds to", raw_train_ds.class_names[i])
# Out:
# Label 0 corresponds to FUNC_BAPI_INQUIRY_CREATEFROMDATA2
# Label 1 corresponds to FUNC_BAPI_MATERIAL_AVAILABILITY
# Label 2 corresponds to FUNC_BAPI_RESERVATION_GETDETAIL
# Label 3 corresponds to FUNC_BAPI_SALESDOCU_CREATEFROMDATA1
# Label 4 corresponds to FUNC_BAPI_SALESORDER_CONFIRMDELVRY
# Label 5 corresponds to FUNC_ENH_REBATE_DRILL_DOWN_DISPLAY
# Label 6 corresponds to FUNC_EXTEND_POSTAL_CODE
# Label 7 corresponds to FUNC_IDOC_INPUT_SALESORDER_CONFIRMD
# Label 8 corresponds to FUNC_MMDA_IM_CONTENT_STOCK_MAP
# Label 9 corresponds to FUNC_MRM_INVOICE_LOCK

# %%
raw_val_ds = tf.keras.utils.text_dataset_from_directory(
    'test000/train', 
    batch_size=batch_size, 
    validation_split=0.2, 
    subset='validation', 
    seed=seed)
# Out:
# Found 10010 files belonging to 10 classes.
# Using 2002 files for validation.

# %%
raw_test_ds = tf.keras.utils.text_dataset_from_directory(
    'test000/test', 
    batch_size=batch_size)
# Out:
# Found 10010 files belonging to 10 classes.

# %%
def custom_standardization(input_data):
  lowercase = tf.strings.lower(input_data)
  stripped_html = tf.strings.regex_replace(lowercase, '<br />', ' ')
  return tf.strings.regex_replace(stripped_html,
                                  '[%s]' % re.escape(string.punctuation),
                                  '')

# %%
max_features = 10000
sequence_length = 250

vectorize_layer = layers.TextVectorization(
    standardize=custom_standardization,
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=sequence_length)

# %%
# Make a text-only dataset (without labels), then call adapt
train_text = raw_train_ds.map(lambda x, y: x)
vectorize_layer.adapt(train_text)

# %%
def vectorize_text(text, label):
  text = tf.expand_dims(text, -1)
  return vectorize_layer(text), label

# %%
# retrieve a batch (of 32 reviews and labels) from the dataset
text_batch, label_batch = next(iter(raw_train_ds))
first_review, first_label = text_batch[0], label_batch[0]
print("Review", first_review)
print("Label", raw_train_ds.class_names[first_label])
print("Vectorized review", vectorize_text(first_review, first_label))
# Out:
# Review tf.Tensor(b'be set on SPACE again EXAMPLE HINTS If no object case field UPDATEFLAG for checkbox must be 1 only fields references are to be written the following fields parameters should the configuration data in the tables ORDERCFGSREF ORDERCFGSINST ORDERCFGSPARTOF ORDERCFGSVALUE created the sales document successfully you will receive the document enter at least sales order header data via structure ORDER via the structure SALESCCARD card identification data on the one parameters Enter the item data via the table ORDERITEMSIN You this DEENLANGSWITCHNOTRANSLATION FUNCTIONALITY Using this method you can create sales allows fields which have been preassigned to default values to line data 7 Possible UPDATEFLAGS U  Change D  In order to be able to read the condition record does not know whether a pricing date is automatically determined number SALESDOCUMENTEX field Any errors that might occur are announced must call up Commit so that changes can be carried of a sales document can be generated with or without documents with items schedule lines and item conditons You must If you are dealing with configurable items you must enter relevant fields or automatically corresponding to Customizing by leaving the conditions as these cannot be linked to the corresponding item in an external system on the other After you have number using R3 you cannot enter any schedule lines or Delete I  Insert EXAMPLE 1Completely delete sales document 2Delete sales documents You can change header data item data schedule sales document item 3Changes to sales documents 4Change configuration HINTS and ORDERCFGSBLOB Scheduling data can be published via the structure relevant fields blank If you decide to enter the item the structure SALESCONDITIONSIN  Credit card data can be published HEADERIN and partner data via the table ORDERPARTNERS as input is an exception If you change it you must fill 1Miminum entries The sales document number must definitely be created out on the database The BAPI BAPITRANSACTIONCOMMIT is available for in the structure SALESDOCUMENT Key fields must always be entered be initialized BINARYRELATIONSHIPTYPE SALESHEADERINREFOBJECTTYPE SALESHEADERINREFOBJECTKEY SALESHEADERINREFDOCTYPE If item conditions SALESCONDITIONSIN which have an X in the box are copied This hand and data regarding an authorization which has taken place it in completely Maintain the quantities and dates via schedule can enter the item number manually by filling out the SALESSCHEDULEIN Document conditions to be created can be entered via U 4 You must always enter key fields if you a checkbox If you decide on the first possibility only line data and configuration data This is a general rule 1 You only need to enter the fields you wish pricing date in the header SALESHEADERIN PRICEDATE as the BAPI fields which have unmatching SPACE are copied In the second to change 2 Select these with an X in the when making a change The Update indicator in ORDERHEADERINX must relevant checkboxes 3 Fill in the UPDATE field with a are entered then it is recommended that you enter a make a change inculding in the checkbox 5 The configuration via the parameter RETURN Using the checkbox The individual components FUNCTIONALITY Using this method you can change or delete always be entered 2Commit control The BAPI does not do a database Commit As a result the application being used', shape=(), dtype=string)
# Label FUNC_BAPI_SALESDOCU_CREATEFROMDATA1
# Vectorized review (<tf.Tensor: shape=(1, 250), dtype=int64, numpy=
# array([[ 12, 193,  34, 240, 493,  29,  31,  17,  87,  58, 107,  28, 453,
#          10, 173,  23,  12,  99,  74,  63, 464,  20,   5,  12, 113,   2,
#          45,  63,  30, 244,   2, 130,   9,   3,   2, 108, 271, 273, 272,
#         270, 100,   2,  24,  35, 160,  14, 111, 204,   2,  35,  33, 105,
#         131,  24,  56, 104,   9,  67,  47,  56,  67,   2,  47, 463, 141,
#         364,   9,  34,   2, 139,  30,  33,   2,  22,   9,  67,   2,  18,
#         163,  14,   6,  46,  21,  49,   6,  71,  14,  16,  84,  24, 492,
#          63, 120,  80, 216, 468,   5, 241, 320,   5,  92,   9, 496, 469,
#         452, 301, 102, 484,   3,  56,   5,  12, 495,   5, 249,   2, 324,
#         203,  79,  40, 476, 322,   7, 257, 116,   4, 194, 321,  27, 462,
#          28, 109, 123,  19, 473, 164,  20, 367,  23, 215, 198,  69, 258,
#          19, 158,  16,  12, 332,  15,   7,  24,  35,  16,  12, 214,  48,
#          36, 450, 138,  48,  54, 172, 304,   8,  22, 485,  14,  23,  17,
#          14,  20, 331,  48, 208,  54,  14,  23,  33,  55,  63,  36, 194,
#         200,   5, 207,  44, 266,   2, 148,  51, 153, 308,  12, 274,   5,
#           2, 200,  22,   3,  41, 275,  25,  34,   2, 135, 494,  14,  80,
#          27,  49, 466,  14, 308,  33, 109, 172, 304,  36, 231, 213, 477,
#          29, 503, 231,  24,  35, 500,  24, 138,  14,  16, 102, 104,   9,
#          22,   9, 172,  24,  35,  22, 499,   5,  24, 138, 498, 130,  31,
#           8, 472, 133]])>, <tf.Tensor: shape=(), dtype=int32, numpy=3>)

# %%
for j in range(len(vectorize_layer.get_vocabulary())):
    print(" ", j, "---> ",vectorize_layer.get_vocabulary()[j])
# Out:
#   0 --->
#   1 --->  [UNK]
#   2 --->  the
#   3 --->  in
#   4 --->  is
#   5 --->  to
#   6 --->  this
#   7 --->  a
#   8 --->  and
#   9 --->  data
#   10 --->  for
#   11 --->  function
#   12 --->  be
#   13 --->  module
#   14 --->  you
#   15 --->  of
#   16 --->  can
#   17 --->  if
#   18 --->  table
#   19 --->  that
#   20 --->  are
#   21 --->  functionality
#   22 --->  item
#   23 --->  must
#   24 --->  sales
#   25 --->  system
#   26 --->  bapi
#   27 --->  number
#   28 --->  field
#   29 --->  example
#   30 --->  parameters
#   31 --->  hints
#   32 --->  delivery
#   33 --->  enter
#   34 --->  on
#   35 --->  document
#   36 --->  or
#   37 --->  from
#   38 --->  material
#   39 --->  it
#   40 --->  not
#   41 --->  an
#   42 --->  parameter
#   43 --->  type
#   44 --->  by
#   45 --->  following
#   46 --->  deenlangswitchnotranslation
#   47 --->  structure
#   48 --->  with
#   49 --->  using
#   50 --->  check
#   51 --->  as
#   52 --->  plant
#   53 --->  furthersourcesofinf
#   54 --->  items
#   55 --->  relevant
#   56 --->  order
#   57 --->  application
#   58 --->  object
#   59 --->  idoc
#   60 --->  status
#   61 --->  stocks
#   62 --->  costs
#   63 --->  fields
#   64 --->  information
#   65 --->  different
#   66 --->  0
#   67 --->  via
#   68 --->  used
#   69 --->  commit
#   70 --->  unplanned
#   71 --->  method
#   72 --->  contains
#   73 --->  stock
#   74 --->  only
#   75 --->  then
#   76 --->  return
#   77 --->  ale
#   78 --->  invoice
#   79 --->  does
#   80 --->  have
#   81 --->  database
#   82 --->  also
#   83 --->  posted
#   84 --->  create
#   85 --->  party
#   86 --->  goods
#   87 --->  no
#   88 --->  entered
#   89 --->  credit
#   90 --->  called
#   91 --->  key
#   92 --->  line
#   93 --->  available
#   94 --->  bnks
#   95 --->  bnkh
#   96 --->  bnkerf
#   97 --->  transferred
#   98 --->  when
#   99 --->  1
#   100 --->  created
#   101 --->  input
#   102 --->  change
#   103 --->  quantity
#   104 --->  header
#   105 --->  at
#   106 --->  customer
#   107 --->  case
#   108 --->  tables
#   109 --->  any
#   110 --->  objects
#   111 --->  will
#   112 --->  use
#   113 --->  written
#   114 --->  has
#   115 --->  exports
#   116 --->  date
#   117 --->  import
#   118 --->  processing
#   119 --->  side
#   120 --->  which
#   121 --->  partner
#   122 --->  shipto
#   123 --->  errors
#   124 --->  was
#   125 --->  layer
#   126 --->  movement
#   127 --->  storage
#   128 --->  selects
#   129 --->  extractor
#   130 --->  configuration
#   131 --->  least
#   132 --->  indicator
#   133 --->  scheduling
#   134 --->  2
#   135 --->  other
#   136 --->  displays
#   137 --->  availability
#   138 --->  documents
#   139 --->  one
#   140 --->  salesdocument
#   141 --->  card
#   142 --->  calls
#   143 --->  logical
#   144 --->  include
#   145 --->  related
#   146 --->  parallel
#   147 --->  locations
#   148 --->  conditions
#   149 --->  quantities
#   150 --->  dates
#   151 --->  atp
#   152 --->  authorization
#   153 --->  these
#   154 --->  currency
#   155 --->  bnkindexs
#   156 --->  bnkindexh
#   157 --->  filled
#   158 --->  changes
#   159 --->  according
#   160 --->  successfully
#   161 --->  about
#   162 --->  orderpartners
#   163 --->  orderitemsin
#   164 --->  occur
#   165 --->  entries
#   166 --->  all
#   167 --->  detailed
#   168 --->  orders
#   169 --->  message
#   170 --->  reservation
#   171 --->  account
#   172 --->  schedule
#   173 --->  checkbox
#   174 --->  transformation
#   175 --->  there
#   176 --->  supports
#   177 --->  support
#   178 --->  selected
#   179 --->  rules
#   180 --->  revaluation
#   181 --->  movements
#   182 --->  industry
#   183 --->  core
#   184 --->  applies
#   185 --->  export
#   186 --->  x
#   187 --->  included
#   188 --->  rule
#   189 --->  special
#   190 --->  debit
#   191 --->  amount
#   192 --->  among
#   193 --->  set
#   194 --->  automatically
#   195 --->  control
#   196 --->  bapitransactioncommit
#   197 --->  situation
#   198 --->  up
#   199 --->  distribution
#   200 --->  corresponding
#   201 --->  make
#   202 --->  agreement
#   203 --->  record
#   204 --->  receive
#   205 --->  manually
#   206 --->  filling
#   207 --->  customizing
#   208 --->  configurable
#   209 --->  blank
#   210 --->  output
#   211 --->  soldto
#   212 --->  division
#   213 --->  i
#   214 --->  generated
#   215 --->  call
#   216 --->  been
#   217 --->  interface
#   218 --->  into
#   219 --->  indicates
#   220 --->  orderheaderin
#   221 --->  s
#   222 --->  receivers
#   223 --->  objkey
#   224 --->  name
#   225 --->  logsys
#   226 --->  executed
#   227 --->  e
#   228 --->  53
#   229 --->  passed
#   230 --->  necessary
#   231 --->  delete
#   232 --->  always
#   233 --->  fill
#   234 --->  sector
#   235 --->  remoteenabled
#   236 --->  plants
#   237 --->  lsetmmdaimsbxbfum
#   238 --->  language
#   239 --->  checked
#   240 --->  space
#   241 --->  default
#   242 --->  result
#   243 --->  out
#   244 --->  should
#   245 --->  exception
#   246 --->  stored
#   247 --->  specified
#   248 --->  value
#   249 --->  read
#   250 --->  wrbtrs
#   251 --->  wrbtrh
#   252 --->  memo
#   253 --->  local
#   254 --->  distributes
#   255 --->  defined
#   256 --->  rebate
#   257 --->  pricing
#   258 --->  so
#   259 --->  hand
#   260 --->  4
#   261 --->  3
#   262 --->  code
#   263 --->  figure
#   264 --->  posting
#   265 --->  changing
#   266 --->  leaving
#   267 --->  required
#   268 --->  determine
#   269 --->  work
#   270 --->  ordercfgsvalue
#   271 --->  ordercfgsref
#   272 --->  ordercfgspartof
#   273 --->  ordercfgsinst
#   274 --->  linked
#   275 --->  external
#   276 --->  sd
#   277 --->  either
#   278 --->  partnrole
#   279 --->  may
#   280 --->  inquiries
#   281 --->  doctype
#   282 --->  format
#   283 --->  w
#   284 --->  types
#   285 --->  sent
#   286 --->  lsbus2032
#   287 --->  converts
#   288 --->  activated
#   289 --->  51
#   290 --->  en
#   291 --->  returned
#   292 --->  lsreservationitems
#   293 --->  enables
#   294 --->  dsuommreswwammreswwareservations
#   295 --->  dsuommresbwamresbwareservations
#   296 --->  bapiret
#   297 --->  assignment
#   298 --->  activity
#   299 --->  respectively
#   300 --->  update
#   301 --->  u
#   302 --->  salesconditionsin
#   303 --->  published
#   304 --->  lines
#   305 --->  eg
#   306 --->  decide
#   307 --->  copied
#   308 --->  cannot
#   309 --->  requirement
#   310 --->  times
#   311 --->  several
#   312 --->  retrieves
#   313 --->  retrieve
#   314 --->  modules
#   315 --->  map
#   316 --->  lsettrds
#   317 --->  initialization
#   318 --->  datasource
#   319 --->  current
#   320 --->  values
#   321 --->  determined
#   322 --->  whether
#   323 --->  variables
#   324 --->  condition
#   325 --->  above
#   326 --->  user
#   327 --->  starting
#   328 --->  results
#   329 --->  receipt
#   330 --->  exit
#   331 --->  dealing
#   332 --->  carried
#   333 --->  meaning
#   334 --->  entire
#   335 --->  verification
#   336 --->  triggered
#   337 --->  none
#   338 --->  meet
#   339 --->  invoiced
#   340 --->  formulae
#   341 --->  distributed
#   342 --->  convert
#   343 --->  conversion
#   344 --->  contain
#   345 --->  characteristic
#   346 --->  summed
#   347 --->  s469
#   348 --->  extended
#   349 --->  zip
#   350 --->  us
#   351 --->  postal
#   352 --->  increases
#   353 --->  codes
#   354 --->  a12345678
#   355 --->  9
#   356 --->  123456789
#   357 --->  12345678
#   358 --->  12345
#   359 --->  10
#   360 --->  taken
#   361 --->  regarding
#   362 --->  place
#   363 --->  need
#   364 --->  identification
#   365 --->  general
#   366 --->  do
#   367 --->  announced
#   368 --->  therefore
#   369 --->  running
#   370 --->  price
#   371 --->  made
#   372 --->  issue
#   373 --->  initiate
#   374 --->  generating
#   375 --->  execute
#   376 --->  every
#   377 --->  dlvitemdata
#   378 --->  dlvitem
#   379 --->  deletion
#   380 --->  deleting
#   381 --->  deleteflag
#   382 --->  confirmation
#   383 --->  sp
#   384 --->  salesorg
#   385 --->  partnnumb
#   386 --->  organization
#   387 --->  numbers
#   388 --->  distrchan
#   389 --->  channel
#   390 --->  assigned
#   391 --->  where
#   392 --->  well
#   393 --->  they
#   394 --->  systems
#   395 --->  standard
#   396 --->  source
#   397 --->  shiptoparty
#   398 --->  serialization
#   399 --->  see
#   400 --->  records
#   401 --->  processed
#   402 --->  outbound
#   403 --->  orderitemsout
#   404 --->  once
#   405 --->  objtype
#   406 --->  objtyp
#   407 --->  names
#   408 --->  more
#   409 --->  messages
#   410 --->  lsserialid
#   411 --->  lsreceivers
#   412 --->  lsidoc
#   413 --->  lsconfirmdelivery
#   414 --->  lscommunicationdocuments
#   415 --->  lsapplicationobjects
#   416 --->  keywords
#   417 --->  inbound
#   418 --->  idocs
#   419 --->  identified
#   420 --->  how
#   421 --->  given
#   422 --->  german
#   423 --->  dsfu3bapisalesorderconfirmdelvry
#   424 --->  dsdelogsyslogical
#   425 --->  dsdechnumchannel
#   426 --->  come
#   427 --->  billingparty
#   428 --->  begin
#   429 --->  bapis
#   430 --->  back
#   431 --->  applications
#   432 --->  bapiinventurweiterinf
#   433 --->  zhreservationheader
#   434 --->  storeloc
#   435 --->  reservations
#   436 --->  resdate
#   437 --->  pertaining
#   438 --->  movetype
#   439 --->  lsreservationheader
#   440 --->  lsreservation
#   441 --->  location
#   442 --->  list
#   443 --->  display
#   444 --->  costctr
#   445 --->  cost
#   446 --->  center
#   447 --->  base
#   448 --->  03
#   449 --->  01
#   450 --->  without
#   451 --->  wish
#   452 --->  updateflags
#   453 --->  updateflag
#   454 --->  unmatching
#   455 --->  select
#   456 --->  second
#   457 --->  salesschedulein
#   458 --->  salesheaderinrefobjecttype
#   459 --->  salesheaderinrefobjectkey
#   460 --->  salesheaderinrefdoctype
#   461 --->  salesheaderin
#   462 --->  salesdocumentex
#   463 --->  salesccard
#   464 --->  references
#   465 --->  recommended
#   466 --->  r3
#   467 --->  pricedate
#   468 --->  preassigned
#   469 --->  possible
#   470 --->  possibility
#   471 --->  orderheaderinx
#   472 --->  ordercfgsblob
#   473 --->  might
#   474 --->  making
#   475 --->  maintain
#   476 --->  know
#   477 --->  insert
#   478 --->  initialized
#   479 --->  individual
#   480 --->  inculding
#   481 --->  headerin
#   482 --->  first
#   483 --->  definitely
#   484 --->  d
#   485 --->  conditons
#   486 --->  components
#   487 --->  completely
#   488 --->  checkboxes
#   489 --->  box
#   490 --->  binaryrelationshiptype
#   491 --->  being
#   492 --->  allows
#   493 --->  again
#   494 --->  after
#   495 --->  able
#   496 --->  7
#   497 --->  5
#   498 --->  4change
#   499 --->  3changes
#   500 --->  2delete
#   501 --->  2commit
#   502 --->  1miminum
#   503 --->  1completely
#   504 --->  zkettrds
#   505 --->  valuated
#   506 --->  sectors
#   507 --->  retrieved
#   508 --->  project
#   509 --->  processes
#   510 --->  placed
#   511 --->  null
#   512 --->  msbxbfum
#   513 --->  mmdaimpargetum
#   514 --->  mmdaimpargetbx
#   515 --->  mmdaimpargetbf
#   516 --->  materials
#   517 --->  lsmmdaimrrds
#   518 --->  lsmmdaimcontentstockselect
#   519 --->  lsmmdai
#   520 --->  lsivnullstocks
#   521 --->  lsevkzbewpauftbest
#   522 --->  lsevkzbewkauftbest
#   523 --->  lsetstock
#   524 --->  lsetmmdaims0icc03
#   525 --->  lsbseg
#   526 --->  lsbkpf
#   527 --->  ls0mmimstock
#   528 --->  ls0mmimbx
#   529 --->  ivnullstocks
#   530 --->  ivmspr
#   531 --->  ivmslb
#   532 --->  ivmsku
#   533 --->  ivmska
#   534 --->  ivmchb
#   535 --->  ivmcha
#   536 --->  ivmbew
#   537 --->  ivmard
#   538 --->  ivmarc
#   539 --->  itqbew
#   540 --->  itplant
#   541 --->  itmspr
#   542 --->  itmslb
#   543 --->  itmsku
#   544 --->  itmska
#   545 --->  itmkol
#   546 --->  itmchb
#   547 --->  itmcha
#   548 --->  itmbew
#   549 --->  itmaterial
#   550 --->  itmard
#   551 --->  itmarc
#   552 --->  itebew
#   553 --->  frequently
#   554 --->  frequent
#   555 --->  free
#   556 --->  fm
#   557 --->  extract
#   558 --->  exists
#   559 --->  enough
#   560 --->  dependencies
#   561 --->  calling
#   562 --->  before
#   563 --->  based
#   564 --->  along
#   565 --->  master
#   566 --->  certain
#   567 --->  cases
#   568 --->  wmdvsx
#   569 --->  wmdvex
#   570 --->  wbs
#   571 --->  uses
#   572 --->  two
#   573 --->  transferring
#   574 --->  today
#   575 --->  time
#   576 --->  still
#   577 --->  shipment
#   578 --->  selecting
#   579 --->  scope
#   580 --->  replenishment
#   581 --->  recorded
#   582 --->  receipts
#   583 --->  provides
#   584 --->  performed
#   585 --->  particular
#   586 --->  partially
#   587 --->  packaging
#   588 --->  owconsignment
#   589 --->  ovreturnable
#   590 --->  override
#   591 --->  overridden
#   592 --->  oqproject
#   593 --->  oesales
#   594 --->  n
#   595 --->  mrpii
#   596 --->  logic
#   597 --->  lead
#   598 --->  latter
#   599 --->  issues
#   600 --->  initial
#   601 --->  group
#   602 --->  future
#   603 --->  exitsaplw61v001
#   604 --->  endleadtme
#   605 --->  end
#   606 --->  enabled
#   607 --->  element
#   608 --->  dialogflag
#   609 --->  depend
#   610 --->  define
#   611 --->  connected
#   612 --->  combination
#   613 --->  but
#   614 --->  both
#   615 --->  attributes
#   616 --->  error
#   617 --->  yes
#   618 --->  tdrseg
#   619 --->  takes
#   620 --->  t169p
#   621 --->  such
#   622 --->  separate
#   623 --->  reads
#   624 --->  posts
#   625 --->  post
#   626 --->  planned
#   627 --->  occurs
#   628 --->  noentryfound
#   629 --->  mrmdistributionbnk
#   630 --->  listed
#   631 --->  ixrech
#   632 --->  iwaers
#   633 --->  iumrechnen
#   634 --->  ibukrs
#   635 --->  ibudat
#   636 --->  ibeznk
#   637 --->  freight
#   638 --->  foreign
#   639 --->  finds
#   640 --->  exceptions
#   641 --->  duty
#   642 --->  during
#   643 --->  customs
#   644 --->  currencyerror
#   645 --->  converted
#   646 --->  containing
#   647 --->  concerned
#   648 --->  company
#   649 --->  calculated
#   650 --->  bnkanhw
#   651 --->  bnkanfw
#   652 --->  bnk
#   653 --->  applicable
#   654 --->  allocated
#   655 --->  whole
#   656 --->  variable
#   657 --->  too
#   658 --->  simultaneously
#   659 --->  sdbonusturnover
#   660 --->  period
#   661 --->  info
#   662 --->  each
#   663 --->  copy
#   664 --->  conditon
#   665 --->  adjusted
#   666 --->  role
#   667 --->  means
#   668 --->  leave
#   669 --->  inquirypartners
#   670 --->  inquiryitemsin
#   671 --->  inquiryheaderin
#   672 --->  inquirycfgsvalue
#   673 --->  inquirycfgsref
#   674 --->  inquirycfgspartof
#   675 --->  inquirycfgsinst
#   676 --->  inquiry
#   677 --->  announed
#   678 --->  try
#   679 --->  routine
#   680 --->  requirements
#   681 --->  numerical
#   682 --->  match
#   683 --->  figures
#   684 --->  entry
#   685 --->  arise
#   686 --->  areas
#   687 --->  process
#   688 --->  functions
#   689 --->  writes
#   690 --->  withoutcommit
#   691 --->  whereby
#   692 --->  we
#   693 --->  usebapitransactioncommit
#   694 --->  unwanted
#   695 --->  unit
#   696 --->  trigger
#   697 --->  those
#   698 --->  ta
#   699 --->  switch
#   700 --->  successful
#   701 --->  structures
#   702 --->  statement
#   703 --->  specify
#   704 --->  soldtoparty
#   705 --->  single
#   706 --->  settings
#   707 --->  sequence
#   708 --->  same
#   709 --->  rolling
#   710 --->  responsible
#   711 --->  reqqty
#   712 --->  remain
#   713 --->  regardless
#   714 --->  quotations
#   715 --->  quotation
#   716 --->  provided
#   717 --->  partners
#   718 --->  parties
#   719 --->  otherwise
#   720 --->  oss
#   721 --->  oldtoparty
#   722 --->  occurred
#   723 --->  occured
#   724 --->  notes
#   725 --->  note
#   726 --->  new
#   727 --->  multiple
#   728 --->  mandatory
#   729 --->  maintained
#   730 --->  lscreatefromdat2
#   731 --->  longer
#   732 --->  logon
#   733 --->  judge
#   734 --->  itself
#   735 --->  involved
#   736 --->  identifying
#   737 --->  hasnt
#   738 --->  furthermore
#   739 --->  further
#   740 --->  exporting
#   741 --->  except
#   742 --->  ensure
#   743 --->  enable
#   744 --->  empty
#   745 --->  dsfu3bapisalesordercreatefromdat2
#   746 --->  distribtion
#   747 --->  controlparameter
#   748 --->  consistent
#   749 --->  business
#   750 --->  bus2032
#   751 --->  bus2031
#   752 --->  bus2030
#   753 --->  bapisalesordercreatefromdat1
#   754 --->  bapiquotationcreatefromdata
#   755 --->  bapiinquirycreatefromdata
#   756 --->  bapiccard
#   757 --->  bapicard
#   758 --->  appears
#   759 --->  api
#   760 --->  allocate
#   761 --->  93091
#   762 --->  reserved
#   763 --->  handling

# %%
train_ds = raw_train_ds.map(vectorize_text)
val_ds = raw_val_ds.map(vectorize_text)
test_ds = raw_test_ds.map(vectorize_text)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
embedding_dim = 16

# %%
model = tf.keras.Sequential([
  layers.Embedding(max_features, embedding_dim),
  layers.Dropout(0.2),
  layers.GlobalAveragePooling1D(),
  layers.Dropout(0.2),
  layers.Dense(1)])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 16)          160000
#
#  dropout_1 (Dropout)         (None, None, 16)          0
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 160017 (625.07 KB)
# Trainable params: 160017 (625.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss=losses.BinaryCrossentropy(from_logits=True),
              optimizer='adam',
              metrics=tf.metrics.BinaryAccuracy(threshold=0.0))

# %%
epochs = 10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs)
# Out:
# Epoch 1/10
# 251/251 [==============================] - 1s 3ms/step - loss: -4.2309 - binary_accuracy: 0.1000 - val_loss: -11.3645 - val_binary_accuracy: 0.0994
# Epoch 2/10
# 251/251 [==============================] - 1s 2ms/step - loss: -22.6613 - binary_accuracy: 0.1001 - val_loss: -37.2484 - val_binary_accuracy: 0.0994
# Epoch 3/10
# 251/251 [==============================] - 0s 2ms/step - loss: -55.6990 - binary_accuracy: 0.1001 - val_loss: -78.2129 - val_binary_accuracy: 0.0994
# Epoch 4/10
# 251/251 [==============================] - 1s 2ms/step - loss: -103.2065 - binary_accuracy: 0.1001 - val_loss: -133.2205 - val_binary_accuracy: 0.0994
# Epoch 5/10
# 251/251 [==============================] - 0s 2ms/step - loss: -164.2135 - binary_accuracy: 0.1001 - val_loss: -201.1693 - val_binary_accuracy: 0.0994
# Epoch 6/10
# 251/251 [==============================] - 0s 2ms/step - loss: -236.8651 - binary_accuracy: 0.1001 - val_loss: -280.9799 - val_binary_accuracy: 0.0994
# Epoch 7/10
# 251/251 [==============================] - 0s 2ms/step - loss: -320.4178 - binary_accuracy: 0.1001 - val_loss: -371.7916 - val_binary_accuracy: 0.0994
# Epoch 8/10
# 251/251 [==============================] - 1s 2ms/step - loss: -415.0373 - binary_accuracy: 0.1001 - val_loss: -473.0316 - val_binary_accuracy: 0.0994
# Epoch 9/10
# 251/251 [==============================] - 1s 2ms/step - loss: -520.7747 - binary_accuracy: 0.1001 - val_loss: -584.3117 - val_binary_accuracy: 0.0994
# Epoch 10/10
# 251/251 [==============================] - 0s 2ms/step - loss: -635.3409 - binary_accuracy: 0.1001 - val_loss: -704.9974 - val_binary_accuracy: 0.0994

# %%
loss, accuracy = model.evaluate(test_ds)

print("Loss: ", loss)
print("Accuracy: ", accuracy)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: -697.3549 - binary_accuracy: 0.1000
# Loss:  -697.3548583984375
# Accuracy:  0.10000000149011612

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
acc = history_dict['binary_accuracy']
val_acc = history_dict['val_binary_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.show()
