# %%
import preprocess as pp

# %%
# This is where we supposed to put the training/testing materal
TARGET_DIR = 'test000'
# This is where we have the documents, named by their labels
SOURCE_DIR = 'base_data_small'
# Text split multiplier
SPLIT_MULTIPLIER = 100
# Number of fake guys
FAKE_GUYS_TRAIN = 10000
FAKE_GUYS_TEST = 10000

# %%
# DO
pp.do_it(SOURCE_DIR, TARGET_DIR, SPLIT_MULTIPLIER, FAKE_GUYS_TRAIN, FAKE_GUYS_TEST)
