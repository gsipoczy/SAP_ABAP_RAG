# %%
import os
import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import losses
from tensorflow.keras.utils import plot_model
from tensorflow.keras import Sequential
print("Tensorflow version:", tf.__version__)

from sklearn.model_selection import train_test_split
# Out:
# /tmp/ipykernel_14879/2193810590.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 2024-02-22 10:37:11.818805: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-22 10:37:11.820111: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
batch_size = 32
seed = 42

raw_train_ds = tf.keras.utils.text_dataset_from_directory(
    'test000/train', 
    batch_size=batch_size, 
    validation_split=0.2, 
    subset='training', 
    seed=seed)
# Out:
# Found 100010 files belonging to 10 classes.
# Using 80008 files for training.

# %%
type(raw_train_ds)
# Out:
# tensorflow.python.data.ops.batch_op._BatchDataset

# %%
train_text = raw_train_ds.map(lambda x, y: x)
train_target = raw_train_ds.map(lambda x, y: y)

# %%
raw_val_ds = tf.keras.utils.text_dataset_from_directory(
    'test000/train', 
    batch_size=batch_size, 
    validation_split=0.2, 
    subset='validation', 
    seed=seed)
# Out:
# Found 100010 files belonging to 10 classes.
# Using 20002 files for validation.

# %%
val_text = raw_val_ds.map(lambda x, y: x)

# %%
vocab_size = 10000

tfidf_vectorizer = tf.keras.layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode='tf-idf',
    ngrams=(2, 3)
)

tfidf_vectorizer.adapt(train_text)

# %%
tfidf_vectorizer.get_vocabulary()[:10]

# %%
vocab_size = 10000

count_vectorizer = tf.keras.layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode='count'
)

count_vectorizer.adapt(train_text)

# %%
count_vectorizer.get_vocabulary()[:10]

# %%
from tensorflow.keras import regularizers

# BUILD MODEL
model = Sequential([
    count_vectorizer,
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0, l2=0.01)),
    layers.Dropout(0.1),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0, l2=0.01)),
    layers.Dropout(0.1),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

history = model.fit(
    train_text, train_target,
    steps_per_epoch=len(train_text),
    epochs=5,
    validation_data=val_text,
    validation_steps=len(val_text)
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 19
#       4 model = Sequential([
#       5     count_vectorizer,
#       6     layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0, l2=0.01)),
#    (...)
#      10     layers.Dense(1, activation='sigmoid')
#      11 ])
#      13 model.compile(
#      14     loss=tf.keras.losses.binary_crossentropy,
#      15     optimizer=tf.keras.optimizers.Adam(),
#      16     metrics=['accuracy']
#      17 )
# ---> 19 history = model.fit(
#      20     train_text,
#      21     steps_per_epoch=len(train_text),
#      22     epochs=5,
#      23     validation_data=val_text,
#      24     validation_steps=len(val_text)
#      25 )
#
# File ~/virtenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...
